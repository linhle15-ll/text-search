# %%
from dotenv import load_dotenv

load_dotenv()

# %%
import json

# load json
fileName = "data/20250612.json"

with open(fileName, "r", encoding="utf-8") as file:
    data = json.load(file)

# %%
from llama_index.core import Document

documents = []
for dp in data:
    documents.append(Document(
        text = dp["label"],
        doc_id = dp["id"],
        metadata = dp,
    ))

# %%
### Retriever

import nest_asyncio
nest_asyncio.apply()

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core.node_parser import SentenceSplitter
from llama_index.llms.openai import OpenAI

# %%
node_parser = SentenceSplitter(chunk_size=512)
nodes = node_parser.get_nodes_from_documents(documents)

# %%
# by default, the node ids are set to random uuids. To ensure same id's per run, we manually set them.
for idx, node in enumerate(nodes):
    node.id_ = f"node_{idx}"

# %%
# OpenAI Embedding
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import Settings

llm = OpenAI(model="gpt-4o-mini")

embed_model = OpenAIEmbedding(embed_batch_size=10, model="text-embedding-3-small")
Settings.embed_model = embed_model #later should not use global varr

# %%
from llama_index.embeddings.openai import OpenAIEmbedding

# Replace 'your-embedding-model' with a valid embedding model available on your OpenAI endpoint
vector_index = VectorStoreIndex(nodes, embed_model=embed_model)
retriever = vector_index.as_retriever(similarity_top_k=5)

# %%
# Try retrieval
retrieved_nodes = retriever.retrieve("Nha khoa Parkway")

from llama_index.core.response.notebook_utils import display_source_node

for node in retrieved_nodes:
    display_source_node(node, source_length=1000)
# Out:
# **Node ID:** node_1038<br>**Similarity:** 0.7513302517515471<br>**Text:** Nha khoa Parkway<br>
# **Node ID:** node_1055<br>**Similarity:** 0.4605765087929772<br>**Text:** Nha khoa Việt Pháp<br>
# **Node ID:** node_733<br>**Similarity:** 0.4573456210590678<br>**Text:** Nha khoa Kim - Cơ sở Quận 2<br>
# **Node ID:** node_347<br>**Similarity:** 0.4570525916335276<br>**Text:** Nha khoa NNS<br>
# **Node ID:** node_760<br>**Similarity:** 0.45505509986383663<br>**Text:** Nha khoa Minh Châu (Nam Từ Liêm, Hà Nội)<br>

# %%
### Build an evaluation dataset of (query, context) pairs

from llama_index.core.evaluation import (
    generate_question_context_pairs,
    EmbeddingQAFinetuneDataset,
)

# %%
qa_dataset = generate_question_context_pairs(
    nodes, llm=llm, num_questions_per_chunk=2
)
# Out:
# 100%|██████████| 3105/3105 [2:18:01<00:00,  2.67s/it]

# %%
queries = qa_dataset.queries.values()
# print(list(queries)[2])
for q in list(queries):
    print(q + '\n')
# Out:
# What services or treatments might be offered at Nha khoa Kim - CS Gò Vấp, considering it is a dental clinic?
#
# In what ways could the location of Nha khoa Kim - CS Gò Vấp impact its accessibility for patients in the surrounding area?
#
# What is the full name of the hospital mentioned in the context information?
#
# In what type of healthcare facility is the "Bệnh viện Đa khoa Thủ Đô" categorized?
#
# What is the name of the dental clinic mentioned in the context information, and in which city is it located?
#
# Identify the specific branch of Nha khoa Hải Âu Sài Gòn that is referenced in the context.
#
# What services or treatments might be offered at Nha khoa Thẩm mỹ Hoàng Gia, considering its focus on aesthetics in dentistry?
#
# How does the branding of Nha khoa Thẩm mỹ Hoàng Gia reflect its commitment to cosmetic dental care?
#
# What type of medical facility is Phòng khám Đa khoa Đại Đông, and what services might it typically offer to patients?
#
# In what ways might Phòng khám Đa khoa Đại Đông contribute to the healthcare needs of the local community?
#
# What is the full name of the clinic mentioned in the context information, and what type of medical facility is it classified as?
#
# Based on the context, what is the significance of the name "Đinh Tiên Hoàng" in relation to the clinic?
#
# What services or treatments might be offered by Nha Khoa Việt Xô, considering it is a dental clinic?
#
# How does the name "Nha Khoa Việt Xô" reflect the cultural or geographical context of the dental practice?
#
# What services or treatments might be offered at Nha khoa 225, considering it is a dental clinic?
#
# How might the name "Nha khoa 225" reflect the location or branding strategy of the dental practice?
#
# What services or treatments might be offered by Nha khoa Việt Chi based on its designation as a dental clinic?
#
# How does the name "Nha khoa Việt Chi" reflect the cultural or geographical context of the dental practice?
#
# What is the primary function of the Trung tâm Y tế huyện Bù Gia Mập in the local community?
#
# How does the Trung tâm Y tế huyện Bù Gia Mập contribute to public health initiatives in the region?
#
# What type of healthcare facility is the Bệnh viện đa khoa khu vực huyện Yên Minh, and what services might it provide to the local community?
#
# In which district is the Bệnh viện đa khoa khu vực huyện Yên Minh located, and how might its location impact the accessibility of healthcare for residents in that area?
#
# What is the name of the clinic mentioned in the context information, and what does the name suggest about its mission or values?
#
# In what ways might the name "Phòng khám Hạnh Phúc - Belco" reflect the services or atmosphere that patients can expect when visiting the clinic?
#
# What is the name of the dental clinic mentioned in the context information, and what is its specific branch location?
#
# Based on the context provided, what type of services might one expect to find at Nha khoa An Định?
#
# What type of medical services does Phòng khám Đa khoa Quốc tế - CHAC provide?
#
# In what ways does Phòng khám Đa khoa Quốc tế - CHAC differentiate itself from other healthcare facilities?
#
# What is the primary focus or specialization of Bệnh viện Phổi Hà Tĩnh?
#
# In what region or city is Bệnh viện Phổi Hà Tĩnh located?
#
# What is the full name of the company mentioned in the context information, and what is its primary focus or industry?
#
# In what capacity does the company operate, and what type of organizational structure does it represent (e.g., public company, private company, etc.)?
#
# What type of medical facility is Phòng khám đa khoa Hưng Sương, and what services might it offer to patients?
#
# In what ways might Phòng khám đa khoa Hưng Sương contribute to the healthcare needs of the local community?
#
# What is the primary function of the Trung tâm Y tế huyện Như Thanh in the local community?
#
# Can you describe the types of services that might be offered at a health center like Trung tâm Y tế huyện Như Thanh?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm Y tế located?
#
# What type of medical facility is Phòng khám đa khoa An Phúc, and what services might it offer to patients?
#
# In what ways might Phòng khám đa khoa An Phúc contribute to the healthcare needs of the community it serves?
#
# What is the primary focus of the Bệnh viện Lao và Bệnh phổi Tây Ninh in terms of healthcare services?
#
# In what region is the Bệnh viện Lao và Bệnh phổi Tây Ninh located?
#
# What type of medical facility is Medic An Khang, and what services might it offer to patients?
#
# In what ways might a multi-specialty clinic like Medic An Khang contribute to community health and wellness?
#
# What is the name of the dental clinic mentioned in the context information, and in which city is it located?
#
# Based on the context provided, what type of services might one expect to find at Nha khoa Việt Pháp - Vĩnh Long?
#
# What is the name of the medical center mentioned in the context information, and where is it located?
#
# Describe the significance of the Pasteur Institute in the context of healthcare in Đà Lạt.
#
# What is the full name of the hospital mentioned in the context information?
#
# In which province or region is Bệnh viện Đa Khoa Đồng Nai located?
#
# What type of medical facility is "PHÒNG KHÁM ĐA KHOA NHÂN ÁI SÀI GÒN," and what services might it offer to patients?
#
# In what city is "PHÒNG KHÁM ĐA KHOA NHÂN ÁI SÀI GÒN" located?
#
# What is the name of the medical facility mentioned in the context information?
#
# Based on the context provided, what can you infer about the focus or specialization of PKĐK MEDICAL TÂM ĐỨC?
#
# What is the name of the dental clinic mentioned in the context information, and who is the associated doctor?
#
# In what field of medicine does Dr. Dương Thái Thành specialize, as indicated in the context information?
#
# What is the full name of the company that operates the Đại Minh Phước General Clinic?
#
# In which type of healthcare facility is Đại Minh Phước categorized?
#
# What is the full name of the healthcare facility mentioned in the context information?
#
# What type of organization operates the healthcare center referred to in the context?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which province is the Trung tâm y tế Cao su located?
#
# What is the full name of the healthcare facility mentioned in the context information?
#
# In which city is the Trạm Y tế Công ty Cổ phần Thành Thành Công located?
#
# What is the full name of the hospital mentioned in the context information?
#
# In what type of institution is Bệnh viện Đại học Võ Trường Toản affiliated?
#
# What services or treatments might be offered at Nha Khoa Việt Nha in Lâm Đồng?
#
# In what ways does Nha Khoa Việt Nha contribute to dental health in the Lâm Đồng region?
#
# What services or specialties might be offered by Nha Khoa Việt Nha in Đắk Lắk, considering it is a dental clinic?
#
# How might the location of Nha Khoa Việt Nha in Đắk Lắk influence its patient demographics and community engagement?
#
# What services or specialties might be offered by Nha khoa Việt Hưng based on its name and context as a dental clinic?
#
# How might the name "Nha khoa Việt Hưng" reflect the cultural or geographical identity of the dental practice?
#
# What services or treatments might be offered at Nha khoa Đakao, considering it is a dental clinic?
#
# How does the name "Nha khoa Đakao" reflect the nature of the business it represents?
#
# What services or treatments might be offered at Nha khoa Sài Gòn based on its name and context?
#
# How does the name "Nha khoa Sài Gòn" reflect the geographical or cultural significance of the dental practice?
#
# What services or treatments might be offered by a dental clinic like Nha khoa Việt Gia?
#
# How does the name "Nha khoa Việt Gia" reflect the cultural or geographical context of the dental practice?
#
# What is the name of the clinic mentioned in the context information, and what type of medical services does it provide?
#
# Who is associated with the clinic, as indicated in the context information?
#
# What is the name of the medical facility located at 52 Nguyễn Trãi, Hà Nội?
#
# In which city is the Phòng Khám Đa Khoa located?
#
# What services or treatments might be offered at Nha khoa Sài Gòn, considering it is a dental clinic?
#
# How does the name "Nha khoa Sài Gòn" reflect the location and focus of the clinic?
#
# What services does Phòng Khám Đa Khoa Thiện Hòa provide to its patients?
#
# How does Phòng Khám Đa Khoa Thiện Hòa ensure the quality of care for its patients?
#
# What type of medical facility is Phòng Khám đa khoa Bách Giai, and what services might it offer to patients?
#
# In what ways might the name "Bách Giai" reflect the values or mission of the clinic?
#
# What type of medical facility is Phòng khám Đa khoa Âu Á, and what services might it offer to patients?
#
# In what ways might Phòng khám Đa khoa Âu Á contribute to the healthcare needs of the community it serves?
#
# What services or specialties might be offered by Nha khoa Nhật Mỹ 2 based on its name and typical practices in dental clinics?
#
# How might the name "Nha khoa Nhật Mỹ" reflect the cultural influences or branding strategies used in the dental industry?
#
# What type of medical facility is Phòng khám Đa khoa Nguyễn Trãi, and what services might it offer to patients?
#
# In what ways might the name "Đa khoa" in Phòng khám Đa khoa Nguyễn Trãi indicate the scope of healthcare services provided at this clinic?
#
# What services or treatments might be offered at Nha Khoa Bảo Ngọc Phổ Yên, considering it is a dental clinic?
#
# In what ways could Nha Khoa Bảo Ngọc Phổ Yên contribute to the oral health education of the local community?
#
# What is the name of the dental clinic mentioned in the context information?
#
# Based on the context provided, what type of services would you expect to find at Phòng khám Nha khoa Minh Châu?
#
# What services or specialties might be offered by Nha Khoa Thảo Ngọc, considering it is a dental clinic?
#
# How does the name "Nha Khoa Thảo Ngọc" reflect the identity or branding of the dental clinic?
#
# What is the name of the pharmacy mentioned in the context information, and who is the associated pharmacist?
#
# Based on the context provided, what role does Hoàng Thị Lê Hảo hold at Nhà thuốc Trọng Tấn?
#
# What type of healthcare facility is Phòng khám đa khoa tư nhân Song Thu, and what services might it provide to patients?
#
# In what ways might a private multi-specialty clinic like Phòng khám đa khoa tư nhân Song Thu differ from public healthcare institutions in terms of patient care and services offered?
#
# What is the primary focus of the Tây Ninh Rehabilitation Hospital as indicated in the context information?
#
# In what ways might the Tây Ninh Rehabilitation Hospital contribute to the community's health and wellness?
#
# What is the name of the hospital mentioned in the context information, and what is its primary focus or specialization?
#
# In what city is the Bệnh viện Phổi Đà Nẵng located?
#
# What is the name of the dental clinic mentioned in the context information, and in which province is it located?
#
# Identify the primary service offered by Nha khoa Ngọc Minh based on the context provided.
#
# What is the name of the medical facility associated with the An Giang Provincial Police?
#
# In which province is the Bệnh xá Công an located?
#
# What type of healthcare facility is Bệnh viện đa khoa tư nhân Lê Ngọc Tùng, and what services might it provide to the community?
#
# In what ways do private hospitals like Bệnh viện đa khoa tư nhân Lê Ngọc Tùng differ from public hospitals in terms of patient care and services offered?
#
# What type of medical services does Công ty cổ phần phòng khám đa khoa Phúc An Sài Gòn provide?
#
# What is the legal structure of Công ty cổ phần phòng khám đa khoa Phúc An Sài Gòn?
#
# What is the name of the medical facility mentioned in the context information?
#
# What type of healthcare services does Phòng khám đa khoa Phạm Huy Tâm provide?
#
# What type of medical facility is Phòng khám đa khoa Hồng Hưng, and what services might it provide to patients?
#
# In what ways might a multi-specialty clinic like Phòng khám đa khoa Hồng Hưng differ from a single-specialty clinic in terms of patient care and treatment options?
#
# What type of healthcare facility is mentioned in the context information, and what is its location?
#
# Can you identify the specific name of the hospital referenced in the context information?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which city is the Trung tâm y tế located?
#
# What is the full name of the organization that operates Phòng khám đa khoa Bình An?
#
# What type of medical facility is Phòng khám đa khoa Bình An classified as?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which city is the Trung tâm y tế located?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which town is the Trung tâm Y tế located?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which city is the Trung tâm y tế located?
#
# What is the name of the dental clinic mentioned in the context information, and where is it located?
#
# In what ways might a cosmetic dental clinic like Nha khoa Thẩm Mỹ Việt Hưng contribute to the overall oral health and aesthetic appearance of its patients?
#
# What services are typically offered at the trung tâm y tế huyện Phú Giáo, and how do they contribute to the health of the local community?
#
# Discuss the role of the trung tâm y tế huyện Phú Giáo in promoting public health initiatives within the huyện Phú Giáo region.
#
# What is the full name of the healthcare facility mentioned in the context information?
#
# What type of organization operates the Trạm Y tế Công ty TNHH Shyang Hung Cheng?
#
# What is the name of the healthcare facility associated with Công ty TNHH Hài Mỹ located in Sài Gòn?
#
# In which city is the Trạm Y tế Công ty TNHH Hài Mỹ situated?
#
# What is the full name of the organization mentioned in the context information, and what type of company is it?
#
# What is the primary function of the "Trạm Y tế" as indicated in the context information?
#
# What type of healthcare facility is mentioned in the context information, and what is its associated company name?
#
# In which geographical location is the multi-specialty clinic (phòng khám đa khoa) affiliated with Thiên Ý Củ Chi located?
#
# What is the full name of the healthcare facility mentioned in the context information?
#
# Which type of organization operates the healthcare facility referred to in the context?
#
# What type of healthcare facility is mentioned in the context information, and what is its specific location?
#
# Can you identify the primary services that a "bệnh viện đa khoa" (general hospital) typically provides, based on your understanding of healthcare facilities?
#
# What is the name of the healthcare facility associated with Công ty TNHH SX Cân Nhơn Hòa?
#
# In what type of organization is the Trạm y tế located?
#
# What type of healthcare facility is mentioned in the context information, and what is its specific location?
#
# Based on the context provided, what services might one expect to find at a "Bệnh viện đa khoa"?
#
# What is the name of the dental clinic mentioned in the context information, and what is its specific location?
#
# Based on the context provided, what type of services might you expect to find at Nha khoa Han Seoul?
#
# What is the primary function of the Trung tâm Kiểm soát Bệnh tật Thành phố Hồ Chí Minh (HCDC)?
#
# How does the HCDC contribute to public health in Ho Chi Minh City?
#
# What services or specialties might be offered by Nha khoa Lê Gia Group based on its designation as a dental group?
#
# How does the branding of Nha khoa Lê Gia Group reflect its mission or values in the field of dentistry?
#
# What is the name of the hospital mentioned in the context information?
#
# What type of hospital is Bệnh viện đa khoa Quang Khởi?
#
# What type of healthcare facility is the Bệnh viện đa khoa huyện Quảng Ninh, and what services might it provide to the local community?
#
# In what ways does the presence of a general hospital like Bệnh viện đa khoa huyện Quảng Ninh impact the health outcomes of the residents in Quảng Ninh district?
#
# What is the full name of the company that operates the Ngân Hà General Clinic?
#
# What type of medical facility is the Ngân Hà General Clinic classified as?
#
# What type of healthcare facility is the Bệnh viện đa khoa tỉnh Phú Thọ, and what services might it provide to the community?
#
# In what ways does the Bệnh viện đa khoa tỉnh Phú Thọ contribute to the overall health and well-being of the population in Phú Thọ province?
#
# What is the full name of the organization that operates the PF4 clinic, and what type of facility is it classified as?
#
# Which branch of the International Perfect Hospital Company does the PF4 clinic belong to?
#
# What is the full name of the company that operates the Sài Gòn Medic General Clinic?
#
# In which city is the Sài Gòn Medic General Clinic located?
#
# What is the full name of the company that operates the Phòng khám đa khoa Sài Gòn - Tân Bình?
#
# In which district is the Phòng khám đa khoa Sài Gòn - Tân Bình located?
#
# What type of medical facility is Phòng khám Đa khoa MEDLATEC Thanh Hóa, and what services might it provide to patients?
#
# In what ways does Phòng khám Đa khoa MEDLATEC Thanh Hóa contribute to the healthcare system in Thanh Hóa?
#
# What is the name of the dental clinic mentioned in the context information, and what is its specific location?
#
# Based on the context provided, what type of services might one expect to find at Nha khoa Han Seoul Cơ sở Hồng Tiến?
#
# What is the name of the dental clinic mentioned in the context information, and in which city is it located?
#
# Identify the type of services that might be offered by a dental clinic like Nha khoa Đoàn Gia in TP. Hồ Chí Minh.
#
# What is the name of the pharmacy mentioned in the context information?
#
# Based on the context provided, what type of establishment is Nhà thuốc Liên Mai?
#
# What is the full name of the company that operates the Nhân Sinh General Clinic?
#
# In what type of healthcare facility is the Nhân Sinh General Clinic categorized?
#
# What is the full name of the company that operates the Bảo Minh General Clinic?
#
# In which type of healthcare facility is the Bảo Minh General Clinic categorized?
#
# What is the full name of the company that operates Phòng khám đa khoa Phúc An Sài Gòn- CN3?
#
# In which city is Phòng khám đa khoa Phúc An Sài Gòn- CN3 located?
#
# What type of healthcare facility is mentioned in the context information, and what is its associated company name?
#
# What is the full name of the company that operates the đa khoa (general clinic) mentioned in the context?
#
# What is the name of the hospital mentioned in the context information?
#
# Describe the type of services that might be expected from a "bệnh viện đa khoa" (general hospital) like Phương Chi.
#
# What is the full name of the organization that operates the Thủ Khoa Huân General Clinic?
#
# Under which type of company is the Thủ Khoa Huân General Clinic classified?
#
# What type of medical facility is Phòng khám đa khoa An Việt, and which company operates it?
#
# What is the full name of the company that owns Phòng khám đa khoa An Việt?
#
# What services or treatments might be offered by Nha khoa Vina, considering it is a dental clinic?
#
# How does the name "Nha khoa Vina" reflect the cultural or linguistic context of the location it serves?
#
# What is the name of the hospital mentioned in the context information?
#
# In which district is the Bệnh viện Quận Bình Tân located?
#
# What is the full name of the hospital mentioned in the context information, and in which district is it located?
#
# Identify the type of healthcare facility described in the context information.
#
# What is the name of the dental clinic mentioned in the context information?
#
# Based on the context provided, what type of services might one expect to find at Nha khoa Sài Gòn S.T?
#
# What type of medical specialty does the Nhất Tâm clinic focus on, and what patient demographic does it primarily serve?
#
# Can you explain the significance of specialized clinics like Nhất Tâm within the healthcare system, particularly in the field of internal medicine for children?
#
# What is the full name of the hospital mentioned in the context information?
#
# In which city is the Hà Nội - Cao Bằng General Hospital located?
#
# What is the name of the hospital mentioned in the context information?
#
# Based on the context provided, what type of institution is Bệnh viện Phương Đông?
#
# What is the name of the medical facility mentioned in the context information, and where is it located?
#
# Describe the type of services that might be offered at a "phòng khám đa khoa" based on your understanding of the term.
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm Y tế located?
#
# What is the primary function of the Trung tâm Y tế huyện Đăk Hà in the local community?
#
# Can you describe the types of services that might be offered at a health center like Trung tâm Y tế huyện Đăk Hà?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm Y tế located?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which city is the Trung tâm Y tế located?
#
# What type of medical facility is described in the context information, and what does its name suggest about the services it offers?
#
# Based on the name "Phòng khám Đa khoa Kỹ Thuật Cao," what might be the implications for the level of technology and expertise available at this clinic?
#
# What is the name of the dental clinic mentioned in the context information, and what is its specific location?
#
# Can you describe the services or specialties that might be offered by a dental clinic like Nha khoa Kim - Cơ sở Tân Bình based on common practices in dental care?
#
# What type of medical facility is "Phòng khám Đa khoa Thế giới," and what services might it offer to patients?
#
# In what ways might "Phòng khám Đa khoa Thế giới" differ from specialized medical clinics?
#
# What services or treatments might be offered by Nha Khoa Singae Dental based on its name and context?
#
# How does the branding of Nha Khoa Singae Dental reflect its focus on dental care?
#
# What is the full name of the medical facility mentioned in the context information, and what is its affiliation with the military?
#
# In which specific unit or organization is the Bệnh xá Quân dân y Đoàn Kinh tế Quốc phòng 78 located?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm Y tế located?
#
# What is the name of the medical facility associated with the police department in Kon Tum province?
#
# In which province is the Bệnh xá Công an located?
#
# What type of medicine does the Bệnh viện Y học cổ truyền tỉnh Bình Dương specialize in?
#
# In which province is the Bệnh viện Y học cổ truyền located?
#
# What is the primary function of the Trung tâm Kiểm soát bệnh tật tỉnh Kon Tum?
#
# In which province is the Trung tâm Kiểm soát bệnh tật located?
#
# What is the full name of the organization that operates Phòng khám Đa khoa Hà Nội - Kon Tum?
#
# Which type of company is responsible for the management of Phòng khám Đa khoa Hà Nội - Kon Tum?
#
# What types of diseases are primarily treated at the Bệnh viện Lao và bệnh phổi, and why is it important to specialize in these conditions?
#
# Discuss the significance of the Bệnh viện Lao và bệnh phổi in the context of public health and disease prevention in the community.
#
# What is the full name of the company that operates the đa khoa clinic mentioned in the context information?
#
# What type of healthcare facility is the Phòng khám đa khoa An Phúc classified as?
#
# What type of healthcare facility is Bệnh viện đa khoa Quốc ánh, and what services might it typically provide to the community?
#
# In what ways do hospitals like Bệnh viện đa khoa Quốc ánh contribute to public health and patient care in their respective regions?
#
# What is the full name of the hospital mentioned in the context information, and in which city is it located?
#
# What type of hospital is the Bệnh viện giao thông vận tải Tp HCM, and what specific services might it provide based on its name?
#
# What is the name of the clinic mentioned in the context information, and where is it located?
#
# Describe the services or specialties that might be expected at a clinic like Medic Hoàn Mỹ Sài Gòn based on common practices in healthcare facilities.
#
# What is the name of the vaccination center mentioned in the context information, and in which province is it located?
#
# Describe the primary services that the Trung tâm tiêm chủng Long Châu may provide to the community in Bình Dương.
#
# What is the name of the hospital mentioned in the context information?
#
# Based on the context provided, what type of institution is Bệnh viện Hạnh Phúc?
#
# What is the name of the hospital mentioned in the context information, and what type of hospital is it?
#
# Can you describe the primary focus or specialty of the Mỹ Đức hospital based on the context provided?
#
# What is the primary focus or specialization of Bệnh viện Phổi Trung ương?
#
# Can you describe the significance of Bệnh viện Phổi Trung ương in the context of respiratory health care in the region?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế huyện Lấp Vò located?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What is the name of the hospital mentioned in the context information?
#
# Can you describe the significance of Bệnh viện Từ Dũ in the healthcare system?
#
# What is the name of the medical facility associated with the police department in Đồng Tháp province?
#
# In which province is the Bệnh xá công an located?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What is the primary function of the Trung tâm Y tế huyện Chợ Mới in the community?
#
# How does the Trung tâm Y tế huyện Chợ Mới contribute to public health initiatives in the region?
#
# What is the primary function of the Trung tâm Y tế huyện Châu Thành in the local community?
#
# Can you describe the types of services that might be offered at a health center like Trung tâm Y tế huyện Châu Thành?
#
# What services or treatments might be offered at Nha khoa Như Ngọc based on its name and context?
#
# How does the name "Nha khoa Như Ngọc" reflect the focus or specialization of the establishment?
#
# What type of medical specialty does the Phòng khám chuyên khoa Tai Mũi Họng Hà Nội focus on?
#
# In what city is the Phòng khám chuyên khoa Tai Mũi Họng located?
#
# What is the name of the vaccination center mentioned in the context information, and in which city is it located?
#
# Identify the specific branch of the VNVC vaccination center referenced in the context information.
#
# What is the name of the dental clinic mentioned in the context information?
#
# Based on the context provided, what type of services might one expect to find at Nha khoa Thanh Phương?
#
# What is the name of the vaccination center mentioned in the context information, and in which district is it located?
#
# Identify the branch of the vaccination center referenced in the context information.
#
# What is the name of the dental clinic mentioned in the context information, and in which city is it located?
#
# Identify the type of services that might be offered by a dental clinic like Nha khoa Wilson Dentistry based on common practices in dentistry.
#
# What is the name of the vaccination center mentioned in the context information?
#
# What services or activities might one expect to find at a vaccination center like Trung tâm tiêm chủng Phú Cường?
#
# What is the full name of the hospital mentioned in the context information, and what type of medicine does it specialize in?
#
# In which province or region is the Bệnh viện Y dược cổ truyền Đồng Nai located?
#
# What is the full name of the organization that operates the Đức Trí General Clinic?
#
# What type of medical facility is Đức Trí, and what is its legal structure?
#
# What type of healthcare facility is referred to in the context information provided?
#
# How might the services offered at a "Bệnh viện Sức khỏe tâm thần" differ from those at a general hospital?
#
# What is the name of the dental clinic mentioned in the context information?
#
# Based on the context provided, what type of services do you think Nha khoa Lê Thành Tâm might offer?
#
# What services or treatments might be offered at Nha Khoa Thẩm Mỹ Phước Trung, considering its focus on dental aesthetics?
#
# How does the name "Nha Khoa Thẩm Mỹ Phước Trung" reflect the mission or specialization of the establishment in the field of dentistry?
#
# What is the name of the hospital mentioned in the context information?
#
# In what type of healthcare facility is the context information set?
#
# What services or specialties might be offered at the Phòng khám Gia đình Hà Nội based on its name and context?
#
# How does the concept of a "family clinic" differ from other types of medical facilities, and what implications might this have for patient care at Phòng khám Gia đình Hà Nội?
#
# What is the name of the clinic mentioned in the context information, and what is its specific location?
#
# Based on the context provided, what type of services or specialties might you expect to find at a clinic named "Happy Baby"?
#
# What services does the Phòng khám Ban Bảo vệ CSSK cán bộ tỉnh provide to its patients?
#
# How does the Phòng khám Ban Bảo vệ CSSK cán bộ tỉnh contribute to the overall health and well-being of provincial officials?
#
# What is the full name of the hospital mentioned in the context information?
#
# In which field of healthcare does Bệnh viện đa khoa Cao su Phú Riềng operate?
#
# What is the full name of the hospital mentioned in the context information, and in which province is it located?
#
# What type of medicine does the Bệnh viện YHCT tỉnh Bình Phước specialize in?
#
# What type of healthcare facility is the Bệnh viện đa khoa huyện Thanh Chương, and what services might it typically provide to the community?
#
# In what ways might the Bệnh viện đa khoa huyện Thanh Chương contribute to the overall health and well-being of the residents in Thanh Chương district?
#
# What type of healthcare facility is Bệnh viện đa khoa khu vực Hồng Ngự, and what services might it provide to the community?
#
# In what ways does the presence of a regional general hospital like Bệnh viện đa khoa khu vực Hồng Ngự impact the local healthcare system and patient access to medical services?
#
# What is the full name of the medical facility mentioned in the context information, and what type of services does it provide?
#
# What is the legal structure of PHÒNG KHÁM ĐA KHOA VẠN PHƯỚC SÓC XOÀI as indicated in the context information?
#
# What type of healthcare facility is the Bệnh viện đa khoa huyện Vĩnh Thạnh, and what services might it provide to the community?
#
# In what ways might the Bệnh viện đa khoa huyện Vĩnh Thạnh contribute to the overall health and well-being of the residents in Vĩnh Thạnh district?
#
# What services or treatments might be offered at Nha khoa Hòa An based on its designation as a dental clinic?
#
# How does the name "Nha khoa Hòa An" reflect the values or mission of the dental practice?
#
# What is the full name of the clinic mentioned in the context information, and what type of medical facility is it classified as?
#
# To which company does the đa khoa clinic belong, as indicated in the context information?
#
# What type of medicine does Bệnh viện Y học cổ truyền - Cần Thơ specialize in?
#
# In which city is Bệnh viện Y học cổ truyền located?
#
# What services or specialties might be offered by a dental clinic like Nha khoa Đức Minh based on common practices in dental care?
#
# How might the name "Nha khoa Đức Minh" reflect the values or mission of the dental clinic in terms of patient care and community service?
#
# What is the name of the vaccination center mentioned in the context information, and what specific branch is highlighted?
#
# What services or activities might be expected at the VNVC vaccination center based on its designation?
#
# What is the name of the vaccination center mentioned in the context information?
#
# In which location is the Thành Phát vaccination center situated?
#
# What services or treatments might be offered at Nha khoa Shinbi, considering it is a dental clinic?
#
# How does the name "Nha khoa Shinbi" reflect the nature of the business it represents?
#
# What is the name of the medical facility mentioned in the context information, and in which district is it located?
#
# Identify the type of medical services offered by Phòng Khám Đa Khoa Liên Tâm based on the context provided.
#
# What type of medical facility is Phòng khám đa khoa Ái Nghĩa Biên Hòa, and what services might it offer to the community?
#
# In what ways do multi-specialty clinics like Phòng khám đa khoa Ái Nghĩa Biên Hòa contribute to the healthcare system in Biên Hòa?
#
# What is the full name of the hospital mentioned in the context information, and in which province is it located?
#
# What type of medicine does the hospital in Quảng Bình specialize in?
#
# What type of medical facility is Phòng khám đa khoa Phương Bình, and what services might it offer to patients?
#
# In what ways might a multi-specialty clinic like Phòng khám đa khoa Phương Bình differ from a single-specialty clinic in terms of patient care and treatment options?
#
# What is the full name of the clinic mentioned in the context information, and what type of medical facility is it classified as?
#
# Identify the specific branch location of the clinic referenced in the context information.
#
# What is the name of the dental clinic mentioned in the context information, and what specific location is associated with it?
#
# Who is the individual associated with the dental clinic Nha khoa Kim, as referenced in the context information?
#
# What type of medical facility is Phòng khám đa khoa Sài Gòn Long Khánh, and what services might it offer to patients?
#
# In what city is Phòng khám đa khoa Sài Gòn Long Khánh located, and how might this influence the patient demographic it serves?
#
# What type of medical facility is Phòng khám đa khoa Tâm Bình An, and what services might it offer to patients?
#
# Based on the name "Phòng khám đa khoa Tâm Bình An," what can be inferred about the values or philosophy of care that this clinic may prioritize?
#
# What services or treatments might be offered at Nha khoa Đại Dương, considering it is a dental clinic?
#
# How might the name "Nha khoa Đại Dương" reflect the values or mission of the dental practice?
#
# What is the primary focus of the Bệnh viện y học cổ truyền Trung Ương in terms of medical practice?
#
# How does the Bệnh viện y học cổ truyền Trung Ương integrate traditional medicine into its healthcare services?
#
# What type of medical facility is Phòng khám Đa khoa Việt Âu, and what services might it provide to patients?
#
# In what ways might Phòng khám Đa khoa Việt Âu contribute to the healthcare needs of the local community?
#
# What services or specialties might be offered by Nha khoa HDR Việt Đức based on its name and context?
#
# How does the name "Nha khoa HDR Việt Đức" suggest its geographical or cultural significance?
#
# What is the name of the dental clinic mentioned in the context information, and where is it located?
#
# Based on the context provided, what services or specialties might one expect to find at a dental clinic like Nha khoa Bảo Ngọc?
#
# What is the official name of the medical facility associated with the Long An Provincial Police?
#
# In which province is the Bệnh xá Công an tỉnh Long An located?
#
# What is the name of the medical facility associated with the provincial police in Tiền Giang?
#
# In which province is the Bệnh xá công an located?
#
# What is the full name of the vaccination center mentioned in the context information, and what specific branch is highlighted?
#
# Can you describe the primary services offered by the VNVC vaccination center based on the context provided?
#
# What services or specialties might be offered by Nha Khoa Minh Ngọc, considering its designation as a dental clinic?
#
# How might the name "Nha Khoa Minh Ngọc" reflect the values or mission of the dental practice?
#
# What is the full name of the organization mentioned in the context information, and what type of medicine do they specialize in?
#
# What is the significance of the term "YHCT" in the context of the organization described?
#
# Who is the medical professional associated with the private clinic mentioned in the context information?
#
# What type of medical facility is referenced in the context information?
#
# What is the name of the clinic mentioned in the context information, and who is the primary physician associated with it?
#
# In which province is the clinic "Phòng khám Nội BS Hùng" located?
#
# What services or treatments might be offered at Nha khoa Huỳnh Kim Dental based on its name and context?
#
# How does the name "Nha khoa Huỳnh Kim Dental" reflect the cultural or linguistic aspects of dental care in its region?
#
# What is the primary function of the Trung tâm Kiểm soát Bệnh tật tỉnh Lạng Sơn?
#
# In what province is the Trung tâm Kiểm soát Bệnh tật located?
#
# What services are likely offered at Phòng Khám Đa Khoa Trí Tâm based on its name and designation as a "Đa Khoa" (multispecialty clinic)?
#
# How might the name "Trí Tâm" reflect the values or mission of the clinic in providing healthcare services?
#
# What are the primary responsibilities of the Ban bảo vệ, chăm sóc sức khỏe cán bộ tỉnh in relation to the health and well-being of provincial officials?
#
# How does the Ban bảo vệ, chăm sóc sức khỏe cán bộ tỉnh contribute to the overall healthcare policies within the province?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What type of medical facility is Phòng Khám Đa Khoa Hoàng Minh, and what services might it offer to patients?
#
# In what ways might Phòng Khám Đa Khoa Hoàng Minh contribute to the healthcare needs of the community it serves?
#
# What is the primary function of the Trung tâm Y tế huyện Cờ Đỏ in the local community?
#
# How does the Trung tâm Y tế huyện Cờ Đỏ contribute to public health initiatives in the region?
#
# What type of healthcare facility is Bệnh viện đa khoa quốc tế S.I.S Cần Thơ, and what services might it provide to the community?
#
# In what city is Bệnh viện đa khoa quốc tế S.I.S located, and how might its international designation impact the quality of care offered?
#
# What type of medical facility is Phòng khám đa khoa Vạn Hạnh Cần Thơ, and what services might it offer to the community?
#
# In what city is Phòng khám đa khoa Vạn Hạnh located, and how might its location impact the accessibility of healthcare for local residents?
#
# What type of medical facility is Phòng khám Đa khoa Bảo Vân, and what services might it typically offer to patients?
#
# In what ways might Phòng khám Đa khoa Bảo Vân contribute to the healthcare needs of the local community?
#
# What type of healthcare facility is mentioned in the context information, and what is its specific location?
#
# Can you identify the primary services that a "bệnh viện đa khoa" (general hospital) typically provides, based on the context of the Sóc Trăng province?
#
# What type of healthcare facility is the Bệnh viện đa khoa Khu vực tỉnh An Giang, and what services might it provide to the community?
#
# In which province is the Bệnh viện đa khoa Khu vực tỉnh An Giang located, and how might its location impact the healthcare services available to the local population?
#
# What is the primary function of the Trung tâm Kiểm soát Bệnh tật Tỉnh Lạng Sơn (CDC Lạng Sơn)?
#
# How does the CDC Lạng Sơn contribute to public health in the province of Lạng Sơn?
#
# What type of healthcare facility is referred to in the context information provided?
#
# In what capacity might the "Bệnh viện đa khoa Tỉnh" serve the local community?
#
# What is the name of the hospital mentioned in the context information?
#
# What type of hospital is Bệnh viện Đa khoa Vạn Phước?
#
# What is the primary focus of the Bệnh viện Phục hồi chức năng in terms of patient care and rehabilitation?
#
# Can you describe the types of therapies or treatments that might be offered at a rehabilitation hospital like Bệnh viện Phục hồi chức năng?
#
# What is the name of the hospital mentioned in the context information, and what type of medical services does it specialize in?
#
# Based on the context provided, what might be the significance of the name "Việt Hàn" in relation to the hospital's identity or mission?
#
# What is the full name of the institution referred to as "PKĐK DÂN Y BIÊN HÒA - CN TRẢNG DÀI"?
#
# In what context or field does the institution "PKĐK DÂN Y BIÊN HÒA - CN TRẢNG DÀI" operate?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What type of medical facility is mentioned in the context information, and what is its associated company name?
#
# What is the full name of the company that operates the mentioned medical clinic?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which town is the Trung tâm y tế thị xã Ngã Năm located?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What type of medical services does the Bệnh viện chuyên khoa Sản - Nhi specialize in?
#
# How does the focus on both obstetrics and pediatrics at Bệnh viện chuyên khoa Sản - Nhi benefit patient care?
#
# What type of healthcare facility is mentioned in the context information, and what is its specific location?
#
# Identify the primary function of the institution referred to in the context information.
#
# What type of medical facility is Phòng khám Đa khoa Bảo Ngọc – Yên Ninh, and what services might it provide to patients?
#
# In what ways might the name "Bảo Ngọc" reflect the values or mission of the healthcare services offered at the clinic?
#
# What is the name of the clinic mentioned in the context information, and in which province is it located?
#
# Describe the type of services that might be offered at a "Phòng khám Đa khoa" based on common practices in general clinics.
#
# What is the name of the hospital mentioned in the context information, and where is it located?
#
# In which district of Hanoi is Bệnh viện Đa khoa Medlatec situated?
#
# What services or treatments might be offered at Nha khoa Thẩm mỹ CDC - Cosmetic Dental Centre that distinguish it from traditional dental clinics?
#
# How does the branding of Nha khoa Thẩm mỹ CDC as a "Cosmetic Dental Centre" reflect the focus on aesthetic dental procedures?
#
# What type of medical facility is Phòng khám đa khoa Thánh Tâm, and what services might it offer to patients?
#
# In what ways might Phòng khám đa khoa Thánh Tâm contribute to the healthcare needs of the community it serves?
#
# What is the full name of the company that operates Phòng khám đa khoa Vũ Cao?
#
# In what type of service does Công ty TNHH DVTM Y tế Phòng khám đa khoa Vũ Cao specialize?
#
# What is the name of the hospital mentioned in the context information?
#
# Based on the context provided, what role does the Bệnh viện Trưng Vương play in the healthcare system?
#
# What is the full name of the hospital mentioned in the context information, and what is its primary focus in healthcare?
#
# In which city is the Hospital of Hematology and Blood Transfusion located?
#
# What services or specialties might be offered at Nha Khoa Sài Gòn Bác Sĩ Lâm, based on its name and context?
#
# How does the title "Bác Sĩ" in Nha Khoa Sài Gòn Bác Sĩ Lâm indicate the qualifications or expertise of the staff at this dental clinic?
#
# What is the full name of the institution referred to as "Bệnh xá Quân Dân Y Trường Cao đẳng nghề Số 8" and what is its affiliation within the military structure?
#
# In what capacity does "Bệnh xá Quân Dân Y Trường Cao đẳng nghề Số 8" serve within the context of military and civilian healthcare?
#
# What is the name of the medical facility mentioned in the context information?
#
# What is the address of the clinic referenced in the document?
#
# What is the name of the dental clinic mentioned in the context information, and what is its specific location?
#
# Based on the context provided, what type of services might one expect to find at Nha khoa Minh Tâm?
#
# What is the name of the dental clinic mentioned in the context information, and what is its specific location or branch referred to in the text?
#
# Based on the context provided, what services or specialties might you expect to find at a dental clinic like Nha khoa Minh Tâm?
#
# What services or treatments are likely offered at Nha Khoa Viplab located in Dịch Vọng, and how might they differ from those at other dental clinics?
#
# In what ways does the location of Nha Khoa Viplab in Dịch Vọng potentially influence its patient demographic and the types of dental services it provides?
#
# What is the name of the hospital mentioned in the context information, and what type of medical services does it specialize in?
#
# Based on the context provided, what can be inferred about the location of Bệnh viện Mắt Thái Nguyên?
#
# What is the name of the dental clinic mentioned in the context information, and who is it associated with?
#
# In which location is the Nha khoa Bảo Việt clinic situated, as indicated in the context information?
#
# What type of medical facility is Phòng khám Đa khoa Bảo Ngọc - Đại Từ, and what services might it offer to patients?
#
# In what ways might the name "Bảo Ngọc" reflect the values or mission of the clinic located in Đại Từ?
#
# What type of medical facility is Phòng khám Đa khoa Đông Phương, and what services might it typically offer to patients?
#
# In what ways might Phòng khám Đa khoa Đông Phương contribute to the healthcare needs of the local community?
#
# What is the name of the dental clinic mentioned in the context information?
#
# Based on the context provided, what type of services might one expect to find at Nha khoa Hồng Phúc?
#
# What services or treatments might be offered at Nha khoa Nhật Sinh – NISSEI dental clinic based on common practices in dental clinics?
#
# How might the name "Nha khoa Nhật Sinh" reflect the values or mission of the dental clinic?
#
# What is the full name of the clinic mentioned in the context information, and what is its specialization?
#
# Where is the clinic located, including the street name and city?
#
# What type of medical facility is Phòng khám Đa khoa Thế Kỷ Mới, and what services might it offer to patients?
#
# In what ways might Phòng khám Đa khoa Thế Kỷ Mới contribute to the healthcare needs of the community it serves?
#
# What is the name of the clinic mentioned in the context information, and in which district is it located?
#
# Identify the type of medical facility described in the context information.
#
# What services or treatments might be offered at Nha khoa Tâm Đức - CS 1, based on common practices in dental clinics?
#
# How might the location or branding of Nha khoa Tâm Đức - CS 1 influence patient perceptions and choices regarding dental care?
#
# What is the name of the clinic mentioned in the context information, and in which district is it located?
#
# Identify the type of medical facility described in the context information.
#
# What is the name of the medical facility associated with the provincial police in Thừa Thiên Huế?
#
# In which province is the Bệnh xá Công an located?
#
# What is the name of the hospital mentioned in the context information?
#
# In which district is the hospital located?
#
# What type of medical facility is Phòng khám đa khoa Thanh Sơn, and what services might it offer to patients?
#
# In what ways might a multi-specialty clinic like Phòng khám đa khoa Thanh Sơn contribute to community health?
#
# What type of medical facility is Phòng khám đa khoa Hồng Bàng, and what services might it offer to patients?
#
# ...
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What services or facilities are typically offered at the Bệnh xá trường Đại học Hùng Vương for students and staff?
#
# How does the Bệnh xá trường Đại học Hùng Vương contribute to the overall health and well-being of the university community?
#
# What is the name of the hospital mentioned in the context information, and what is its affiliation?
#
# In which province is the Bệnh viện Công an located?
#
# What type of healthcare facility is Phòng khám đa khoa FUSHICO, and what educational institution is it associated with?
#
# In what ways might the collaboration between Phòng khám đa khoa FUSHICO and Trường Cao đẳng Y Dược Phú Thọ benefit students in their medical training?
#
# What type of healthcare facility is Bệnh viện đa khoa Tư nhân Hùng Vương, and what services might it provide to the community?
#
# How does the designation "Tư nhân" in the name of Bệnh viện đa khoa Tư nhân Hùng Vương indicate the ownership structure of the hospital?
#
# What type of medical facility is described in the context information, and what is its primary focus?
#
# In what type of location is the clinic situated, as indicated in the context information?
#
# What is the full name of the company that operates the Âu Cơ Phú Hà General Clinic?
#
# In which type of medical facility is the Âu Cơ Phú Hà located?
#
# What is the full name of the company that operates the Đức Chí General Clinic?
#
# In which field does Đức Chí General Clinic specialize?
#
# What is the full name of the clinic mentioned in the context information, and what type of services does it provide?
#
# Which company is associated with the Hùng Vương Chân Mộng clinic, and what is its focus area?
#
# What type of healthcare facility is Bệnh viện đa khoa Việt Đức, and what services might it provide to the community?
#
# In what ways does Bệnh viện đa khoa Việt Đức contribute to the overall healthcare system in Vietnam?
#
# What type of medical facility is mentioned in the context information, and which organization does it belong to?
#
# In which city is the đa khoa clinic located, as stated in the context information?
#
# What is the name of the clinic mentioned in the context information, and under which company does it operate?
#
# In which province is the Công ty Cổ phần Âu Cơ Phú Thọ located, as indicated in the context information?
#
# What is the name of the clinic mentioned in the context information, and under which company is it operated?
#
# In which province is the Công ty cổ phần Sao Việt Phú Thọ located, as indicated in the context information?
#
# What type of healthcare facility is Phòng khám đa khoa Vĩnh Phú, and which company is it affiliated with?
#
# What is the full name of the company that operates Phòng khám đa khoa Vĩnh Phú?
#
# What type of medical facility is Phòng khám đa khoa Bình Minh, and what services might it offer to patients?
#
# In what ways might Phòng khám đa khoa Bình Minh contribute to the healthcare needs of the local community?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What is the name of the hospital mentioned in the context information, and what is its primary focus or specialization?
#
# In which city is the Bệnh viện Ung thư located?
#
# What is the full name of the hospital mentioned in the context information?
#
# In which province is Bệnh viện Đa khoa hữu nghị Nghệ An 2 located?
#
# What type of healthcare facility is the Bệnh viện đa khoa khu vực Cầu Ngang, and what services might it provide to the community?
#
# In what ways does the presence of a regional general hospital like Bệnh viện đa khoa khu vực Cầu Ngang impact the healthcare accessibility for the local population?
#
# What is the full name of the organization that the Phòng khám đa khoa 103 is affiliated with?
#
# What type of healthcare facility is Phòng khám đa khoa 103?
#
# What type of healthcare facility is the Bệnh viện đa khoa tỉnh Vĩnh Phúc, and what services might it provide to the community?
#
# In what province is the Bệnh viện đa khoa tỉnh Vĩnh Phúc located, and how might this geographical context influence its operations and patient demographics?
#
# What is the full name of the hospital mentioned in the context information, and where is it located?
#
# What is the significance of "Cơ sở 2" in relation to Bệnh viện Đại Học Y Dược TPHCM?
#
# What is the primary focus of the Bệnh viện Lao Phổi Quảng Ninh in terms of healthcare services?
#
# Can you describe the significance of specialized hospitals like Bệnh viện Lao Phổi Quảng Ninh in the management and treatment of respiratory diseases?
#
# What is the full name of the hospital mentioned in the context information, and what type of medical services does it specialize in?
#
# In which city is the Bệnh viện Bệnh Nhiệt Đới located?
#
# What is the full name of the hospital mentioned in the context information, and what city is it located in?
#
# What type of medical services does the Bệnh viện Phục Hồi Chức Năng TP HCM specialize in?
#
# What type of healthcare facility is Bệnh viện Đa khoa Quốc tế Thành Đô, and what services might it provide to patients?
#
# In what ways might Bệnh viện Đa khoa Quốc tế Thành Đô differ from other types of hospitals in terms of its international designation?
#
# What is the primary focus of the Bệnh viện Tai Mũi Họng Sài Gòn in terms of medical specialties?
#
# How does the Bệnh viện Tai Mũi Họng Sài Gòn contribute to the healthcare needs of the community it serves?
#
# What is the full name of the hospital mentioned in the context information, and in which city is it located?
#
# What type of institution is the Bệnh viện Đại học Y Dược TP HCM, and what might be its primary focus or specialty?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế huyên Dầu Tiếng located?
#
# What is the full name of the healthcare facility mentioned in the context information?
#
# In which industry does the Công ty Cổ phần may mặc Bình Dương operate?
#
# What is the full name of the healthcare facility mentioned in the context information?
#
# What type of organization is "TRẠM Y TẾ CÔNG TY TNHH CHÍ HÙNG"?
#
# What type of medicine does Bệnh viện Y học cổ truyền Phú Yên specialize in, and how does it differ from conventional medicine?
#
# Can you describe the significance of traditional medicine in the healthcare system of Phú Yên as represented by Bệnh viện Y học cổ truyền?
#
# What type of services does Công ty TNHH Dược - Phòng khám đa khoa Thiên Ân provide to its clients?
#
# What is the full name of the company mentioned in the context information?
#
# What type of medical conditions does the Bệnh viện Phong và Da liễu specialize in treating?
#
# Can you describe the significance of the name "Bệnh viện Phong và Da liễu" in relation to its services?
#
# What type of medical facility is Phòng khám đa khoa An Hà, and what services might it offer to patients?
#
# In what ways might Phòng khám đa khoa An Hà contribute to the healthcare needs of the community it serves?
#
# What is the full name of the hospital mentioned in the context information, and what type of medicine does it specialize in?
#
# Can you describe the significance of Bệnh viện YHCT Hùng Vương in the healthcare system?
#
# What type of medical facility is Phòng khám đa khoa chất lượng cao Tuệ Tâm, and what services might it offer to patients?
#
# How does the designation "chất lượng cao" (high quality) in the name of Phòng khám đa khoa Tuệ Tâm reflect the standards or expectations of care provided at this clinic?
#
# What type of healthcare facility is Phòng khám đa khoa An Bình, and what services might it typically offer to patients?
#
# In what ways might Phòng khám đa khoa An Bình contribute to the community's health and well-being?
#
# What is the name of the company that operates the health station mentioned in the context information?
#
# In which sector does the health station belong, as indicated by its affiliation with a specific company?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What is the name of the hospital mentioned in the context information?
#
# In what type of medical facility is the term "Y khoa" used, as referenced in the context?
#
# What services or specialties might be offered at Phòng khám Quốc tế LCCG based on its designation as an international clinic?
#
# How does the designation "Quốc tế" (international) influence the expectations of patients seeking care at Phòng khám Quốc tế LCCG?
#
# What is the name of the eye clinic mentioned in the context information?
#
# Based on the context provided, what type of medical services would you expect to find at Phòng khám Mắt Hải Yến?
#
# What is the specialty of the clinic mentioned in the context information?
#
# Who is the doctor associated with the clinic?
#
# What services or specialties might be offered by Nha khoa Bảo Việt located on Hoàng Đạo Thúy, and how do they contribute to dental health?
#
# In what ways could the location of Nha khoa Bảo Việt on Hoàng Đạo Thúy impact its accessibility for patients seeking dental care?
#
# What is the address of Phòng khám Nhi Đồng 315, and in which district is it located?
#
# In which ward can you find the Chi nhánh of Phòng khám Nhi Đồng 315 mentioned in the context?
#
# What is the name of the hospital mentioned in the context information, and what type of medical services does it specialize in?
#
# In which city is the Bệnh Viện Mắt PRIMA located?
#
# What is the address of Phòng Khám ACC as mentioned in the context information?
#
# What type of establishment is Phòng Khám ACC?
#
# What is the name of the dental clinic located in Tân Bình, TP. Hồ Chí Minh?
#
# In which city is Nha khoa Minh Đức situated?
#
# What are the primary services typically offered by a hospital, and how do they contribute to patient care?
#
# Discuss the importance of hospitals in the healthcare system and the role they play in community health.
#
# What is the full name of the hospital mentioned in the context information?
#
# What is the designation of the specific branch of the hospital referenced in the document?
#
# What is the name of the medical facility mentioned in the context information, and in which city is it located?
#
# What type of medical services does Phòng Khám Đa Khoa Vạn Phước Cửu Long provide?
#
# What type of medical specialty does Phòng khám chuyên khoa nhi 123 focus on?
#
# What services might you expect to find at a pediatric clinic like Phòng khám chuyên khoa nhi 123?
#
# What is the name of the dental clinic mentioned in the context information, and who is it associated with?
#
# In what area or locality is the dental clinic "Nha khoa Bác Sĩ Trung Long Biên và Cộng Sự" located?
#
# What type of medical facility is Phòng khám Đa khoa Nancy, and what services might it offer to patients?
#
# In what ways might Phòng khám Đa khoa Nancy contribute to the healthcare needs of the local community?
#
# What is the name of the pharmacy mentioned in the context information?
#
# Based on the context provided, what type of establishment is Nhà thuốc Nhân Hưng?
#
# What is the full name of the company associated with the Phòng Chẩn trị Y học cổ truyền mentioned in the context information?
#
# In what field does the Công ty TNHH Thương mại Sản xuất Y tế Mai Anh operate?
#
# What is the name of the clinic mentioned in the context information, and what type of medical services does it provide?
#
# What is the address of the Phòng khám Đa khoa Hoàng Long?
#
# What is the full address of Phòng khám Nhi đồng 315, including the specific location and district?
#
# In which xã (commune) is Phòng khám Nhi đồng 315 located?
#
# What is the name of the healthcare facility mentioned in the context information, and in which district is it located?
#
# Identify the type of healthcare service provided by the Trạm y tế xã Xuân Nộn.
#
# What is the full name of the healthcare facility mentioned in the context information?
#
# In what type of organization is the Trạm Y tế Công ty TNHH Đông Nam located?
#
# What is the full name of the healthcare facility mentioned in the context information, and what type of company is it classified as?
#
# In which city or region is the Phòng khám Đa khoa Thăng Long located, based on the context provided?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What is the full name of the clinic mentioned in the context information, and what type of services does it provide?
#
# Which company is associated with the Hợp Nhất clinic, and what are the primary areas of focus for this company?
#
# What type of medical facility is Phòng khám đa khoa Xuân Mai, and what services might it offer to patients?
#
# In what ways might a multi-specialty clinic like Phòng khám đa khoa Xuân Mai contribute to community health?
#
# What type of medical facility is Phòng khám đa khoa Đức Giang, and where is it located?
#
# Can you describe the services that might be offered at a general clinic like Phòng khám đa khoa Đức Giang?
#
# What type of medical facility is Phòng khám Đa khoa Công Vĩnh, and what services might it offer to patients?
#
# In what ways might Phòng khám Đa khoa Công Vĩnh contribute to the healthcare needs of the community it serves?
#
# What type of medicine does Bệnh viện Y học cổ truyền Phúc Thượng specialize in?
#
# Can you describe the significance of traditional medicine in the context of healthcare as represented by Bệnh viện Y học cổ truyền Phúc Thượng?
#
# What type of healthcare facility is Bệnh Viện YHCT Tâm Phúc, and which company does it belong to?
#
# Identify the relationship between Bệnh Viện YHCT Tâm Phúc and Công ty cổ phần Y tế Tâm Phúc.
#
# What type of medical facility is Phòng khám đa khoa Lan Sơn, and what services might it offer to patients?
#
# In what ways might Phòng khám đa khoa Lan Sơn contribute to the healthcare needs of the local community?
#
# What type of medical facility is Phòng khám đa khoa Trường Đăng, and what services might it offer to patients?
#
# In what ways might the name "Trường Đăng" reflect the values or mission of the clinic?
#
# What type of medical facility is Phòng khám Đa khoa Hồng Ngọc, and what services might it offer to patients?
#
# In what ways might Phòng khám Đa khoa Hồng Ngọc contribute to the healthcare needs of the community it serves?
#
# What services or specialties does Bệnh viện Medlatec offer to its patients?
#
# How does Bệnh viện Medlatec ensure the quality of care and patient satisfaction in its healthcare services?
#
# What is the name of the hospital mentioned in the context information, and in which city is it located?
#
# Identify the type of healthcare facility referenced in the context information.
#
# What is the name of the hospital mentioned in the context information, and in which city is it located?
#
# Describe the type of services or specialties that might be expected at a hospital like Bệnh viện Tâm Trí Đà Nẵng based on its name.
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What is the name of the healthcare facility mentioned in the context information?
#
# In which district is the Trung tâm y tế located?
#
# What is the name of the hospital mentioned in the context information?
#
# What type of hospital is Bệnh viện quân y 109?
#
# What is the name of the hospital mentioned in the context information?
#
# In what capacity is the hospital referred to in the context information?
#
# What is the primary focus of the Bệnh Viện Phục Hồi Chức Năng Đà Nẵng in terms of patient care and rehabilitation services?
#
# Can you describe the significance of the location of Bệnh Viện Phục Hồi Chức Năng Đà Nẵng in relation to its accessibility for patients in the region?

# %%
### save json (optional)
qa_dataset.save_json("eval_dataset.json")

# %%
# [optional] load
qa_dataset = EmbeddingQAFinetuneDataset.from_json("eval_dataset.json")

# %%
### RetrieverEvaluator for Retrieval Evaluation

include_cohere_rerank = False

if include_cohere_rerank:
    # !uv pip install cohere -q

# %%
from llama_index.core.evaluation import RetrieverEvaluator

metrics = ["hit_rate", "mrr", "precision", "recall", "ap", "ndcg"]

if include_cohere_rerank:
    metrics.append(
        "cohere_rerank_relevancy"  # requires COHERE_API_KEY environment variable to be set
    )

retriever_evaluator = RetrieverEvaluator.from_metric_names(
    metrics, retriever=retriever
)

# %%
# try it out on a sample query
sample_id, sample_query = list(qa_dataset.queries.items())[0]
sample_expected = qa_dataset.relevant_docs[sample_id]

eval_result = retriever_evaluator.evaluate(sample_query, sample_expected)
print(eval_result)

# %%
# try it out on an entire dataset
eval_results = await retriever_evaluator.aevaluate_dataset(qa_dataset)
print(eval_results)

# %%
### Build Retriever with LlamaIndex
import pandas as pd


def display_results(name, eval_results):
    """Display results from evaluate."""

    metric_dicts = []
    for eval_result in eval_results:
        metric_dict = eval_result.metric_vals_dict
        metric_dicts.append(metric_dict)

    full_df = pd.DataFrame(metric_dicts)

    columns = {
        "retrievers": [name],
        **{k: [full_df[k].mean()] for k in metrics},
    }

    if include_cohere_rerank:
        crr_relevancy = full_df["cohere_rerank_relevancy"].mean()
        columns.update({"cohere_rerank_relevancy": [crr_relevancy]})

    metric_df = pd.DataFrame(columns)

    return metric_df

# %%
display_results("top-2 eval", eval_results)

# %% [markdown]
# ## Metrics Interpretation
# Good reference: https://www.pinecone.io/learn/offline-evaluation/
#
# ### Core Metrics Explained
#
# #### **Precision & Recall**
# Remember "recall thừa precision đủ" :D
# - **Recall**: How many relevant results are returned out of all relevant documents that exist
# - **Precision**: How many returned results are actually relevant
#
# **Example**: Query "How many Hieu in this team?"
# - Returns 5 results: [Hieu1, Hieu2, Hoai, Hieu3, Dinh Anh]
# - Total Hieus in database: 3
# - **Recall = 3/3 = 1.0** (100% - found all Hieus)
# - **Precision = 3/5 = 0.6** (60% - 3 out of 5 results are relevant)
#
# #### **Hit Rate (Hit Ratio)**
# Measures whether at least one relevant document appears in the top-k results.
# - **Formula**: Number of queries with ≥1 relevant result / Total queries
# - **Range**: 0.0 to 1.0 (higher is better)
# - **Use case**: Good for understanding if your system finds ANY relevant results
#
# #### **MRR (Mean Reciprocal Rank)**
# Measures how high the first relevant result appears in the ranking.
# - **Formula**: Average of (1/rank_of_first_relevant_result) across all queries
# - **Range**: 0.0 to 1.0 (higher is better)
# - **Example**:
#   - Query 1: First relevant at rank 2 → RR = 1/2 = 0.5
#   - Query 2: First relevant at rank 1 → RR = 1/1 = 1.0
#   - **MRR = (0.5 + 1.0) / 2 = 0.75**
#
# #### **AP (Average Precision)**
# Considers both precision and the ranking position of relevant documents.
# - **Formula**: Average of precision@k for each relevant document found
# - **Range**: 0.0 to 1.0 (higher is better)
# - **Use case**: Rewards systems that rank relevant docs higher
#
# #### **NDCG (Normalized Discounted Cumulative Gain)**
# Most sophisticated metric - considers relevance scores and ranking positions.
# - **Formula**: DCG@k / IDCG@k (normalized against ideal ranking)
# - **Range**: 0.0 to 1.0 (higher is better)
# - **Use case**: Best for graded relevance (not just binary relevant/irrelevant)
#
# ### Applying to Our Healthcare Dataset
#
# **Dataset Context**: Vietnamese healthcare facility names and addresses
# - **Documents**: Structured data with facility names, types, and locations
# - **Queries**: Generated questions about specific facilities
# - **Challenge**: Vietnamese text, abbreviations (BV vs Bệnh Viện), case sensitivity
#
# **Expected Performance Patterns**:
# 1. **High Hit Rate** (>0.8): Most queries should find at least one relevant facility
# 2. **Moderate MRR** (0.5-0.7): Exact matches might not always rank #1 due to text variations
# 3. **Variable Precision**: Depends on query specificity and facility name uniqueness
# 4. **Good Recall**: Vector embeddings should capture semantic similarity
#
# **Optimization Strategies**:
# - **Low Hit Rate**: Improve text preprocessing, consider hybrid search (BM25 + Vector)
# - **Low MRR**: Fine-tune embedding model, adjust similarity thresholds
# - **Low Precision**: Increase similarity threshold, reduce top-k results
# - **Low Recall**: Decrease similarity threshold, increase top-k results
